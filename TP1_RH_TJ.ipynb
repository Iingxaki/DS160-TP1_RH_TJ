# %% [markdown]
# # About Skyrim Weapons

# %%
# Install the required libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the data set
data=pd.read_csv('LeagueofLegends.csv')
#visualize the top five rows in the data using the head function
data.head()
# Out:
#   League  Year  Season    Type blueTeamTag  bResult  rResult redTeamTag  \
# 0  NALCS  2015  Spring  Season         TSM        1        0         C9
# 1  NALCS  2015  Spring  Season         CST        0        1        DIG
# 2  NALCS  2015  Spring  Season         WFX        1        0         GV
# 3  NALCS  2015  Spring  Season         TIP        0        1         TL
# 4  NALCS  2015  Spring  Season         CLG        1        0         T8
#
#    gamelength                                           golddiff  ...  \
# 0          40  [0, 0, -14, -65, -268, -431, -488, -789, -494,...  ...
# 1          38  [0, 0, -26, -18, 147, 237, -152, 18, 88, -242,...  ...
# 2          40  [0, 0, 10, -60, 34, 37, 589, 1064, 1258, 913, ...  ...
# 3          41  [0, 0, -15, 25, 228, -6, -243, 175, -346, 16, ...  ...
# 4          35  [40, 40, 44, -36, 113, 158, -121, -191, 23, 20...  ...
#
#   redMiddleChamp                                      goldredMiddle  \
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
#data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7620 entries, 0 to 7619
# Data columns (total 57 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   League            7620 non-null   object
#  1   Year              7620 non-null   int64
#  2   Season            7620 non-null   object
#  3   Type              7620 non-null   object
#  4   blueTeamTag       7582 non-null   object
#  5   bResult           7620 non-null   int64
#  6   rResult           7620 non-null   int64
#  7   redTeamTag        7583 non-null   object
#  8   gamelength        7620 non-null   int64
#  9   golddiff          7620 non-null   object
#  10  goldblue          7620 non-null   object
#  11  bKills            7620 non-null   object
#  12  bTowers           7620 non-null   object
#  13  bInhibs           7620 non-null   object
#  14  bDragons          7620 non-null   object
#  15  bBarons           7620 non-null   object
# ...

# %%
#data columns
data.columns
# Out:
# Index(['League', 'Year', 'Season', 'Type', 'blueTeamTag', 'bResult', 'rResult',
#        'redTeamTag', 'gamelength', 'golddiff', 'goldblue', 'bKills', 'bTowers',
#        'bInhibs', 'bDragons', 'bBarons', 'bHeralds', 'goldred', 'rKills',
#        'rTowers', 'rInhibs', 'rDragons', 'rBarons', 'rHeralds', 'blueTop',
#        'blueTopChamp', 'goldblueTop', 'blueJungle', 'blueJungleChamp',
#        'goldblueJungle', 'blueMiddle', 'blueMiddleChamp', 'goldblueMiddle',
#        'blueADC', 'blueADCChamp', 'goldblueADC', 'blueSupport',
#        'blueSupportChamp', 'goldblueSupport', 'blueBans', 'redTop',
#        'redTopChamp', 'goldredTop', 'redJungle', 'redJungleChamp',
#        'goldredJungle', 'redMiddle', 'redMiddleChamp', 'goldredMiddle',
#        'redADC', 'redADCChamp', 'goldredADC', 'redSupport', 'redSupportChamp',
#        'goldredSupport', 'redBans', 'Address'],
#       dtype='object')

# %%
#data shape 
data.shape
# Out:
# (7620, 57)

# %%
#print the shape of the data set
print(f'In the Data rows is {data.shape[0]} and column is {data.shape[1]}')
# Out:
# In the Data rows is 7620 and column is 57

# %%
#Checking the null values in the data 
data.isna().sum().sort_values(ascending=False)
# Out:
# blueTeamTag         38
# blueMiddle          37
# blueADC             37
# redSupport          37
# redTeamTag          37
# redTop              37
# redADC              37
# blueTop             37
# blueSupport         37
# redMiddle           37
# blueJungle          28
# redJungle           24
# blueSupportChamp     0
# goldblueSupport      0
# goldblueADC          0
# blueADCChamp         0
# goldblueMiddle       0
# blueBans             0
# League               0
# redTopChamp          0
# goldredTop           0
# blueMiddleChamp      0
# goldredJungle        0
# redMiddleChamp       0
# goldredMiddle        0
# redADCChamp          0
# goldredADC           0
# redSupportChamp      0
# goldredSupport       0
# redBans              0
# redJungleChamp       0
# blueJungleChamp      0
# goldblueJungle       0
# bDragons             0
# Season               0
# Type                 0
# bResult              0
# rResult              0
# gamelength           0
# golddiff             0
# ...

# %%
# Understanding the Stastics in the data set
data.describe()
# Out:
#               Year      bResult      rResult   gamelength
# count  7620.000000  7620.000000  7620.000000  7620.000000
# mean   2016.280971     0.544094     0.455906    37.012598
# std       0.848200     0.498085     0.498085     7.983238
# min    2014.000000     0.000000     0.000000    17.000000
# 25%    2016.000000     0.000000     0.000000    31.000000
# 50%    2016.000000     1.000000     0.000000    36.000000
# 75%    2017.000000     1.000000     1.000000    41.000000
# max    2018.000000     1.000000     1.000000    95.000000

# %%
sns.pairplot(data,hue='Season')

# %%
datanew=data[['Year','bResult','rResult','gamelength']]

# %%
corr=data[['Year','bResult','rResult','gamelength']].corr()

# %%
# Visualize the Correlation map
sns.heatmap(corr,annot=True)
plt.title("Visualizing the correlation map")
plt.show()

# %% [markdown]
# #### Observations:
# - In the Correlation map it's clearly understand some columns are have negative correlation and some have positive correlation, which means some have inverse relationships and some have direct relationships with each other.
# - However, the bResult (blue team's result) and the rResult(red team's result) are absolute inverse relationship is explainable as they are opposite teams and comprises of complementary data.

# %% [markdown]
# # Explore Data Analysis (EDA Process)

# %% [markdown]
# ### Identify the which year most of the LoL games posted in the data

# %%
data['Year'].value_counts()
# Out:
# Year
# 2017    3311
# 2016    2494
# 2015    1496
# 2018     241
# 2014      78
# Name: count, dtype: int64

# %%
data['Year'].value_counts().sort_values(ascending=False)\
.plot(kind='bar',figsize=(8,6),title="Year wise LoL games in the data")
plt.xlabel("Year")
plt.ylabel("Count of values")
plt.show()

# %% [markdown]
# ### Observations:
# #### bar chart
# - Year 2017 has most of the matches posted compare to the other years
# - In 2014 we received the least amount of matches compared to other years

# %% [markdown]
# ### Identify the which tournament most of the LoL games posted in the data

# %%
data['League'].value_counts()
# Out:
# League
# LCK      1445
# NALCS    1272
# EULCS    1099
# LMS       778
# TCL       653
# OPL       458
# WC        308
# CBLoL     301
# LCL       281
# LJL       258
# LLN       242
# CLS       175
# IEM       138
# MSI       111
# RR        101
# Name: count, dtype: int64

# %%
data['League'].value_counts().sort_values(ascending=False)\
.plot(kind='bar',figsize=(8,6),title="Region's League wise LoL games in the data")
plt.xlabel("Region's League")
plt.ylabel("Count of values")
plt.show()

# %% [markdown]
# ### Observations:
# #### bar chart
# - LCK has the highest amount of matches posted.
# - RR has the lowest amount of matches posted.

# %% [markdown]
# ### Identify the which type of matches have in the data set using the pie chart

# %%
data['Type'].value_counts()
# Out:
# Type
# Season           5653
# Playoffs          775
# International     658
# Promotion         391
# Regional          143
# Name: count, dtype: int64

# %%
data['Type'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',figsize=(8,6),title="To Visualize the match types in the data",explode=[0.05,0.04,0.05,0.06,0.07],
    labels=['Season','Playoffs','International','Promotional','Regional'],
    autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ### Observations:
#
# #### Pie Chart
# - Most of the matches posted were seasonal.
# - Least matches posted were regional.

# %% [markdown]
# ### Create histogram to understanding game length with region

# %%
sns.histplot(data=data,x='gamelength' ,hue='League',kde=True)
plt.title("Understanding game length by Region")
plt.xlabel("game length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Observations:
# - From the histogram we observed some interesting things about game length along with region.
# - In the histogram most of the game length went from 25-45 min. It seems like LCK also had more games posted in that same range.

# %% [markdown]
# ### Create histogram to understanding game length with match type

# %%
sns.histplot(data=data,x='gamelength' ,hue='Type',kde=True)
plt.title("Understanding game length by match type")
plt.xlabel("game length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Observations:
# - From the histogram we observed some interesting things about game length along with match type.
# - In the histogram most of the game length went from 25-45 min. It seems like Seasonal matches also had more games posted in that same range.

# %% [markdown]
# ### Visualize the bar chart the average game length for blue team's result win or loss

# %%
data.groupby(['bResult'])['gamelength'].mean().sort_values(ascending=False)\
.plot(kind='bar',title="Sum of the game length in with blue team result",figsize=(8,6),color=['#F7F2E0','#0B3B0B'])
plt.xlabel("blue team result")
plt.ylabel("mean of game length")
plt.show()

# %% [markdown]
# ### Visualize the bar chart the average game length for blue team's Jungle Champion picked

# %%
data.groupby(['blueJungleChamp'])['gamelength'].mean().sort_values(ascending=False)\
.plot(kind='bar',title="Sum of the game length in with blue Jungle Champ",figsize=(8,6),color=['#4B610B','#610B5E','#E3CEF6','#F5F6CE','#D0A9F5','#F6E3CE'])
plt.xlabel("blue team Jungle Champion")
plt.ylabel("mean of game length")
plt.show()

# %% [markdown]
# ### Observations:
# - From the chart we observed that Xin zhao has the highest average game length.
# - From the chart we observed that Leblanc has the lowest average game length.

# %% [markdown]
# # conclusion:
# #### We take the League of Legends data from the kaggle website and Data Some the data Preprocessing setps based on the above columns we create some EDA part in the part we answerd differnt question.
